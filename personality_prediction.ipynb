# %% [markdown]
# <a href="https://colab.research.google.com/github/Malavika-0/Personality-Prediction/blob/main/personality_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/projectml/data.csv')
df
# Out:
#         Age  Gender  Education  Introversion Score  Sensing Score  \
# 0      21.0  Female          1             5.89208       2.144395
# 1      24.0  Female          1             2.48366       3.206188
# 2      26.0  Female          1             7.02910       6.469302
# 3      30.0    Male          0             5.46525       4.179244
# 4      31.0  Female          0             3.59804       6.189259
# ...     ...     ...        ...                 ...            ...
# 43739  26.0    Male          1             8.88656       5.118399
# 43740  29.0    Male          0             2.71470       6.851956
# 43741  25.0  Female          0             2.00982       6.544036
# 43742  23.0    Male          0             7.23553       4.876780
# 43743  21.0    Male          0             1.88310       4.055642
#
#        Thinking Score  Judging Score    Interest Personality
# 0             7.32363       5.462224        Arts        ENTP
# ...

# %% [markdown]
# **UNDERSTANDING DATA**

# %%
df.head()
# Out:
#     Age  Gender  Education  Introversion Score  Sensing Score  Thinking Score  \
# 0  21.0  Female          1             5.89208       2.144395         7.32363
# 1  24.0  Female          1             2.48366       3.206188         8.06876
# 2  26.0  Female          1             7.02910       6.469302         4.16472
# 3  30.0    Male          0             5.46525       4.179244         2.82487
# 4  31.0  Female          0             3.59804       6.189259         5.31347
#
#    Judging Score Interest Personality
# 0       5.462224     Arts        ENTP
# 1       3.765012  Unknown        INTP
# 2       5.454442   Others        ESFP
# 3       5.080477   Sports        ENFJ
# 4       3.677984   Others        ISFP

# %%
df.tail()
# Out:
#         Age  Gender  Education  Introversion Score  Sensing Score  \
# 43739  26.0    Male          1             8.88656       5.118399
# 43740  29.0    Male          0             2.71470       6.851956
# 43741  25.0  Female          0             2.00982       6.544036
# 43742  23.0    Male          0             7.23553       4.876780
# 43743  21.0    Male          0             1.88310       4.055642
#
#        Thinking Score  Judging Score    Interest Personality
# 43739         8.48784       5.331942        Arts        ENTP
# 43740         0.25519       3.623678     Unknown        ISFP
# 43741         6.63911       6.201555  Technology        ISTJ
# 43742         2.41671       4.654016        Arts        ENFP
# 43743         2.25678       5.976738     Unknown        INFP

# %%
df.isna().sum()
# Out:
# Age                   0
# Gender                0
# Education             0
# Introversion Score    0
# Sensing Score         0
# Thinking Score        0
# Judging Score         0
# Interest              0
# Personality           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1028

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.dtypes
# Out:
# Age                   float64
# Gender                 object
# Education               int64
# Introversion Score    float64
# Sensing Score         float64
# Thinking Score        float64
# Judging Score         float64
# Interest               object
# Personality            object
# dtype: object

# %%
df.describe()
# Out:
#                 Age     Education  Introversion Score  Sensing Score  \
# count  42716.000000  42716.000000        42716.000000   42716.000000
# mean      27.399874      0.234455            4.648648       5.757710
# std        4.896950      0.423663            2.903699       1.245533
# min       18.000000      0.000000            0.000150       0.000000
# 25%       24.000000      0.000000            2.126148       4.921852
# 50%       27.000000      0.000000            4.366155       6.146764
# 75%       30.000000      0.000000            7.150157       6.610954
# max       52.000000      1.000000            9.999920       9.803837
#
#        Thinking Score  Judging Score
# count    42716.000000   42716.000000
# mean         5.357428       5.366713
# std          2.901552       1.448086
# min          0.000320       0.000000
# 25%          2.830253       4.480033
# 50%          5.663500       5.723904
# 75%          7.866093       6.397870
# max          9.999770      10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42716 entries, 0 to 42715
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 42716 non-null  float64
#  1   Gender              42716 non-null  object
#  2   Education           42716 non-null  int64
#  3   Introversion Score  42716 non-null  float64
#  4   Sensing Score       42716 non-null  float64
#  5   Thinking Score      42716 non-null  float64
#  6   Judging Score       42716 non-null  float64
#  7   Interest            42716 non-null  object
#  8   Personality         42716 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 2.9+ MB

# %% [markdown]
# **BOX PLOT - OUTLIERS**

# %%
for i in df:
  if df[i].dtype=='int' or df[i].dtype=='float':
    plt.figure(figsize=(6,4))
    #plt.show
    plt.title(i)
    plt.boxplot(df[i])

# %%
for col in df:
  if df[col].dtype=='object':
    print(df[col].value_counts())
    print("")
    print()
# Out:
# Gender
# Male      23598
# Female    19118
# Name: count, dtype: int64
#
#
# Interest
# Unknown       15087
# Arts           8249
# Sports         6774
# Others         6654
# Technology     5952
# Name: count, dtype: int64
#
#
# Personality
# ENTP    2734
# INTP    2734
# ESFP    2734
# ENFJ    2734
# ISFP    2734
# ISFJ    2734
# ESTJ    2734
# INFP    2734
# ESTP    2734
# ENFP    2734
# INTJ    2734
# ESFJ    2734
# INFJ    2734
# ISTP    2734
# ENTJ    2734
# ISTJ    1706
# Name: count, dtype: int64

# %%
sns.boxplot(x='Personality', y='Introversion Score', data=df)
plt.xticks(rotation=90)
plt.title('Introversion Score by Personality Type')
plt.show()

# %% [markdown]
# **HEATMAP - CORRELATION**

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.figure(figsize=(6,4))
plt.show()

# %% [markdown]
# **CHARTS FOR BETTER UNDERSTANDING OF DATA**

# %%
df['Introversion Score'].plot(kind='hist', bins=20, title='Introversion Score')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.figure(figsize=(6, 4))
plt.show()

# %%
df['Sensing Score'].plot(kind='hist', bins=20, title='Sensing Score')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.figure(figsize=(6, 4))
plt.show()

# %%
df['Thinking Score'].plot(kind='hist', bins=20, title='Thinking Score')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.figure(figsize=(4, 2))
plt.show()

# %%
# Loop through the columns and draw countplot for object type columns
for column in df.columns:
    if df[column].dtype == 'object':
        plt.figure(figsize=(6, 4))  # Optional: Adjust the size of the plot
        sns.countplot(data=df, x=column)
        plt.title(f'Count Plot for {column}')
        plt.xticks(rotation=90)  # Rotate x-axis labels if necessary
        plt.show()

# %%
# Set a general style for plots
sns.set(style="whitegrid")

# Plot 1: Age distribution
plt.figure(figsize=(6, 4))
sns.histplot(df['Age'], bins=20, kde=True, color='skyblue')
plt.title('Age Distribution', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
# Plot 2: Score distributions (Introversion, Sensing, Thinking, Judging)
plt.figure(figsize=(6, 4))
for score in ['Introversion Score', 'Sensing Score', 'Thinking Score', 'Judging Score']:
    sns.kdeplot(df[score], label=score, fill=True, alpha=0.4)
plt.title('Distribution of Personality Scores', fontsize=16)
plt.xlabel('Score', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend()
plt.show()

# %%
# Plot 3: Boxplot of Scores by Gender
plt.figure(figsize=(6, 2))
sns.boxplot(data=df.melt(id_vars=['Gender'], value_vars=['Introversion Score', 'Sensing Score', 'Thinking Score', 'Judging Score']),
            x='variable', y='value', hue='Gender', palette='Set3')
plt.title('Scores by Gender', fontsize=16)
plt.xlabel('Score Type', fontsize=12)
plt.ylabel('Score Value', fontsize=12)
plt.legend(title='Gender', fontsize=10)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **FEATURE ENGINEERING**

# %%
df['Age Group'] = df['Age'].apply(lambda x: 'Young' if x<=27 else 'Middle-Aged' if x<=39 else 'Old')

# %%
df['Education']=df['Education'].apply(lambda x: 'Graduate-Level or Higher' if x==1 else 'Undergraduate or high-school-level or Uneducated')

# %%
df.drop(columns='Age',inplace=True)

# %%
df.groupby('Age Group').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.figure(figsize=(5,2))
plt.show()

# %%
# Loop through other categorical columns and create a count plot
for column in df.select_dtypes(include='object').columns:
    if column != 'Age Group':  # Skip Age Group if it exists
        plt.figure(figsize=(6, 4))  # Optional: Adjust the size of the plot
        sns.countplot(x='Age Group', hue=column, data=df)
        plt.title(f'Count Plot of Age Group vs {column}')
        plt.xticks(rotation=45)  # Rotate x-axis labels if necessary
        plt.show()

# %%
figsize = (6, 2 * len(df['Gender'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Education', y='Gender', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-66-4203d0f39436>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='Education', y='Gender', inner='box', palette='Dark2')

# %%
df
# Out:
#        Gender                                         Education  \
# 0      Female                          Graduate-Level or Higher
# 1      Female                          Graduate-Level or Higher
# 2      Female                          Graduate-Level or Higher
# 3        Male  Undergraduate or high-school-level or Uneducated
# 4      Female  Undergraduate or high-school-level or Uneducated
# ...       ...                                               ...
# 42711  Female  Undergraduate or high-school-level or Uneducated
# 42712    Male                          Graduate-Level or Higher
# 42713    Male  Undergraduate or high-school-level or Uneducated
# 42714    Male  Undergraduate or high-school-level or Uneducated
# 42715    Male  Undergraduate or high-school-level or Uneducated
#
#        Introversion Score  Sensing Score  Thinking Score  Judging Score  \
# 0                 5.89208       2.144395         7.32363       5.462224
# ...

# %%
for i in df:
  if df[i].dtype=='object':
    print(f'{i} : {df[i].nunique()}')
# Out:
# Gender : 2
# Education : 2
# Interest : 5
# Personality : 16
# Age Group : 3

# %% [markdown]
# **Label Encoding and One-Hot Encoding**

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# List of categorical columns
object_lst = ['Gender','Education', 'Age Group', 'Interest']
encoder = LabelEncoder()
dict1 = {}

# Label encoding for categorical features
for i in object_lst:
    dict1[i] = LabelEncoder()
    df[i] = dict1[i].fit_transform(df[i])

# One-Hot encoding for the 'Personality' column
onehot = OneHotEncoder(sparse_output=False, drop='first')
personality_encoded = onehot.fit_transform(df[['Personality']])

# Convert the one-hot encoded 'Personality' into a DataFrame
personality_df = pd.DataFrame(personality_encoded, columns=[f'Personality_{i}' for i in range(personality_encoded.shape[1])])

# %% [markdown]
# **Prepare Data for Training**

# %%
# Select features for training
x = df[['Gender', 'Education', 'Introversion Score', 'Sensing Score', 'Thinking Score',
        'Judging Score', 'Interest', 'Age Group']]

# The target variable is the one-hot encoded 'Personality'
y = personality_df

# Convert 'y' into single class labels (argmax to get class index)
y = np.argmax(y.values, axis=1)

# Apply Min-Max Scaling
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

# Fit the scaler on training data (x) and transform it
x_scaled = minmax.fit_transform(x)

# %%
# Loop through the dictionary to get the mappings for each encoder
inverse_mappings = {}

for column, encoder in dict1.items():
    # Inverse transform the encoded labels
    inverse_mapping = dict(zip(encoder.transform(encoder.classes_), encoder.classes_))
    inverse_mappings[column] = inverse_mapping

# Display the inverse mappings
for column, inverse_mapping in inverse_mappings.items():
    print(f"'{column}':")
    print(inverse_mapping)
    print()
# Out:
# 'Gender':
# {0: 'Female', 1: 'Male'}
#
# 'Education':
# {0: 'Graduate-Level or Higher', 1: 'Undergraduate or high-school-level or Uneducated'}
#
# 'Age Group':
# {0: 'Middle-Aged', 1: 'Old', 2: 'Young'}
#
# 'Interest':
# {0: 'Arts', 1: 'Others', 2: 'Sports', 3: 'Technology', 4: 'Unknown'}

# %%
df.columns
# Out:
# Index(['Gender', 'Education', 'Introversion Score', 'Sensing Score',
#        'Thinking Score', 'Judging Score', 'Interest', 'Personality',
#        'Age Group'],
#       dtype='object')

# %% [markdown]
# **Train-Test Split**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x_scaled,y,random_state=42,test_size=0.3)

# %% [markdown]
# **Feature Selection using RFE**

# %%
# Feature Selection using Recursive Feature Elimination (RFE)
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

# RFE for selecting the top 10 features
rfe = RFE(estimator=RandomForestClassifier(), n_features_to_select=10)
x_train_rfe = rfe.fit_transform(x_train, y_train)  # Fit on training data
x_test_rfe = rfe.transform(x_test)  # Transform the test data based on fitted RFE model
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_rfe.py:300: UserWarning: Found n_features_to_select=10 > n_features=8. There will be no feature selection and all features will be kept.
#   warnings.warn(

# %% [markdown]
# **Model Training and Evaluation**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score

# Define models for training and evaluation
models = [
    LogisticRegression(max_iter=1000),  # Logistic Regression
    KNeighborsClassifier(),             # K-Nearest Neighbors
    SVC(),                              # Support Vector Classifier
    GaussianNB(),                       # Naive Bayes
    DecisionTreeClassifier()            # Decision Tree
]

# Train and evaluate each model
for model in models:
    model.fit(x_train_rfe, y_train)  # Train the model
    y_pred = model.predict(x_test_rfe)  # Predict on test data

    print(model)
    print(f'Accuracy: {round((accuracy_score(y_test, y_pred)) * 100)}%')  # Print accuracy
    print(classification_report(y_test, y_pred))  # Print detailed classification report
    print()
# Out:
# LogisticRegression(max_iter=1000)
# Accuracy: 77%
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79      1638
#            1       0.77      0.74      0.75       838
#            2       0.83      0.68      0.75       786
#            3       0.74      0.80      0.77       815
#            4       0.78      0.73      0.75       796
#            5       0.74      0.85      0.79       837
#            6       0.79      0.79      0.79       841
#            7       0.80      0.76      0.78       817
#            8       0.84      0.71      0.77       802
#            9       0.74      0.80      0.77       817
#           10       0.79      0.72      0.75       854
#           11       0.73      0.86      0.79       811
#           12       0.77      0.77      0.77       795
#           13       0.73      0.73      0.73       510
#           14       0.75      0.82      0.78       858
#
# ...

# %% [markdown]
# **Hyperparameter Tuning with GridSearchCV**

# %%
from sklearn.model_selection import GridSearchCV

# Define models for hyperparameter tuning
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    # "SVC": SVC(),
    "Naive Bayes": GaussianNB(),
    "Decision Tree": DecisionTreeClassifier()
}

# Hyperparameter grids for tuning
param_grids = {
    "Logistic Regression": {
        'C': [0.1, 1, 10],
        'solver': ['liblinear', 'lbfgs'],
        'max_iter': [100, 200, 300]
    },
    "K-Nearest Neighbors": {
        'n_neighbors': [3, 5, 7, 9],
        'weights': ['uniform', 'distance'],
        'algorithm': ['auto', 'ball_tree', 'kd_tree']
    },
    # "SVC": {
    #     'C': [0.1, 1, 10],
    #     'kernel': ['linear', 'rbf', 'poly'],
    #     'gamma': ['scale', 'auto'],
    #     'degree': [3, 5]
    # },
    "Naive Bayes": {
        'var_smoothing': [1e-9, 1e-8, 1e-7]
    },
    "Decision Tree": {
        'max_depth': [3, 5, 10, None],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'criterion': ['gini', 'entropy']
    }
}

# Perform grid search for hyperparameter tuning
for model_name, model in models.items():
    print(f"Optimizing {model_name}...")
    grid_search = GridSearchCV(
        model,
        param_grids[model_name],
        cv=5,
        n_jobs=-1,
        verbose=2,
        scoring='accuracy'  # Scoring metric
    )
    grid_search.fit(x_train_rfe, y_train)  # Fit the grid search on RFE-transformed training data

    # Output best parameters and score
    print(f"Best parameters for {model_name}: {grid_search.best_params_}")
    print(f"Best cross-validated score for {model_name}: {round(grid_search.best_score_ * 100, 2)}%")
    print()

    # Get the best model
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(x_test_rfe)  # Predict on test data

    # Evaluate the best model performance
    print(f"Test Accuracy for {model_name}: {round(accuracy_score(y_test, y_pred) * 100, 2)}%")
    print(classification_report(y_test, y_pred))
    print()
# Out:
# Optimizing Logistic Regression...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best parameters for Logistic Regression: {'C': 10, 'max_iter': 300, 'solver': 'lbfgs'}
# Best cross-validated score for Logistic Regression: 77.83%
#
# Test Accuracy for Logistic Regression: 77.54%
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80      1638
#            1       0.77      0.75      0.76       838
#            2       0.81      0.70      0.75       786
#            3       0.75      0.79      0.77       815
#            4       0.77      0.76      0.76       796
#            5       0.76      0.84      0.80       837
#            6       0.78      0.79      0.79       841
#            7       0.79      0.76      0.77       817
#            8       0.81      0.73      0.77       802
#            9       0.77      0.77      0.77       817
#           10       0.77      0.73      0.75       854
# ...

# %% [markdown]
# **Using the Best Model to Predict Personality**

# %%
# Access the best model after grid search
best_model = grid_search.best_estimator_

# Print the best model
print("Best Model after Tuning:", best_model)
# Out:
# Best Model after Tuning: DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=4,
#                        min_samples_split=10)

# %%
# Now you can use this `best_model` for training and prediction.
best_model.fit(x_train_rfe, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=4,
#                        min_samples_split=10)

# %%
def predict_personality():

    # Input numerical features from the user
    Gender = input("Enter Gender (Male/Female): ").strip()
    Age_Group = input("Enter Age Group (Young/Middle-Aged/Old): ").strip()
    Education = int(input("Enter Education level (as integer, e.g., 1 for High School, 2 for Bachelor's, etc.): "))
    Introversion_Score = float(input("Enter Introversion Score: "))
    Sensing_Score = float(input("Enter Sensing Score: "))
    Thinking_Score = float(input("Enter Thinking Score: "))
    Judging_Score = float(input("Enter Judging Score: "))
    Interest = input("Enter Interest category (as string, e.g., 'Arts', 'Science', etc.): ").strip()

    # Process categorical features
    gender_encoded = dict1["Gender"].transform([Gender])
    age_group_encoded = dict1["Age Group"].transform([Age_Group])

    try:
        interest_encoded = dict1["Interest"].transform([Interest])
    except ValueError:
        print(f"Unknown category '{Interest}' encountered for Interest. Using default encoding (0).")
        interest_encoded = [0]  # Default encoding for unseen categories

    # Combine numerical and encoded categorical features
    x_num = np.array([[gender_encoded[0], Education, Introversion_Score, Sensing_Score, Thinking_Score, Judging_Score, age_group_encoded[0]]])
    x_combined = np.hstack([x_num, interest_encoded.reshape(1, -1)])

    # Apply feature scaling using the already fitted scaler
    x_scaled = minmax.transform(x_combined)

    # Predict using the best model
    prediction = best_model.predict(x_scaled)

    # Convert the predicted label to one-hot encoding
    one_hot_prediction = np.zeros(personality_encoded.shape[1])
    one_hot_prediction[prediction] = 1

    # Decode the one-hot encoded personality output
    predicted_personality = onehot.inverse_transform(one_hot_prediction.reshape(1, -1))

    print(f"Predicted Personality: {predicted_personality[0][0]}")

predict_personality()
# Out:
# Enter Gender (Male/Female): Female
# Enter Age Group (Young/Middle-Aged/Old): Old
# Enter Education level (as integer, e.g., 1 for High School, 2 for Bachelor's, etc.): 1
# Enter Introversion Score: 4.5
# Enter Sensing Score: 3.2
# Enter Thinking Score: 1.3
# Enter Judging Score: 5.4
# Enter Interest category (as string, e.g., 'Arts', 'Science', etc.): Arts
# Predicted Personality: ENFP
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
df.sample(1)

#	Female	1	5.89208	2.144395	7.32363	5.462224	Arts	ENTP	Young

# 'Gender':
# {0: 'Female', 1: 'Male'}

# 'Education':
# {0: 'Graduate-Level or Higher', 1: 'Undergraduate or high-school-level or Uneducated'}

# 'Age Group':
# {0: 'Middle-Aged', 1: 'Old', 2: 'Young'}

# 'Interest':
# {0: 'Arts', 1: 'Others', 2: 'Sports', 3: 'Technology', 4: 'Unknown'}
# Out:
#        Gender  Education  Introversion Score  Sensing Score  Thinking Score  \
# 28765       0          1             2.27686       3.873538         3.52883
#
#        Judging Score  Interest Personality  Age Group
# 28765       6.224012         0        INFJ          0

# %%
import pickle

# Save the best model after grid search
with open('best_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)

# Save the scaler (Min-Max Scaler)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(minmax, f)

# Save the OneHotEncoder used for the 'Personality' column
with open('onehot_encoder.pkl', 'wb') as f:
    pickle.dump(onehot, f)

# Save the dictionary of LabelEncoders for categorical columns
with open('label_encoders.pkl', 'wb') as f:
    pickle.dump(dict1, f)

# %%
# Download the pickle files for future use
from google.colab import files

files.download('best_model.pkl')
files.download('scaler.pkl')
files.download('onehot_encoder.pkl')
files.download('label_encoders.pkl')
